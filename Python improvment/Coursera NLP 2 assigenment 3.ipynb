# %%
data ="""
I have a pen.\nI have an apple. \nAh\nApple pen.\n
"""

# %%
import math
import random
import numpy as np
import pandas as pd
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hamza\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hamza\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk import word_tokenize

# %%
sentences = data.split("\n")

# %%
sentences = ["Sky is blue.", "Leaves are green.", "Roses are red."]

# %%
tokenized_sentences = []

# %%
for sentence in sentences: # complete this line
    
    # Convert to lowercase letters
    sentence = sentence.lower()
    
    # Convert into a list of words
    tokenized = nltk.word_tokenize(sentence)
    
    # append the list of words to the list of lists
    tokenized_sentences.append(tokenized)

# %%
tokenized_sentences
# Out:
# [['sky', 'is', 'blue', '.'],
#  ['leaves', 'are', 'green', '.'],
#  ['roses', 'are', 'red', '.']]

# %%
word_counts = {'hello':2}

# %%
word = 'hello3'

# %%
if word not in word_counts.keys():
    print ("yes")
# Out:
# yes

# %%
for word, count in word_counts,pair

# %%
print(word_counts.keys())
# Out:
# dict_keys(['hello'])

# %%
start_token='<s>'
end_token = '<e>'
n=2

# %%
L = [1,2,3,4]
L.append(end_token)

for i in range (0,n):
    L.insert(0, start_token)
    
L
# Out:
# ['<s>', '<s>', 1, 2, 3, 4, '<e>']

# %%
# better approach 
L = [1,2,3,4]
L = [start_token] * n + L + [end_token] 
L
# Out:
# ['<s>', '<s>', 1, 2, 3, 4, '<e>']

# %%
L = [1,2,3,4]
t = tuple(L)
t[1:n+1]
t
# Out:
# (1, 2, 3, 4)

# %%
t = ("s","f")
t = t + ("3",)
t
# Out:
# ('s', 'f', '3')

# %%
dic = {"first":1,"second":2,"third":3 }

print (dic.get("first",0)) #used  to get the value of the key and 0 if the key is not existed

for word, prob in dic.items():
    print (word, prob)
# Out:
# 1
# first 1
# second 2
# third 3

# %%
start_with = 5

if start_with != 2 :
    print(1)
# Out:
# 1

# %%
word = "what_the"

print(word[:4])
# Out:
# what
